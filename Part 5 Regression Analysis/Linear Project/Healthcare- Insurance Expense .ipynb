# %% [markdown]
# <div style="padding:20px;
#             color:white;
#             margin:10;
#             font-size:170%;
#             text-align:left;
#             display:fill;
#             border-radius:5px;
#             background-color:#CA6F1E;
#             overflow:hidden;
#             font-weight:700"><span style='color:#283747'></span>"Predicting Insurance Charges." </div>

# %% [markdown]
# Develop a model to predict the insurance charges (**charges**). This model can help the insurance company in setting premiums more accurately.

# %% [markdown]
# - [1. Load the dataset](#1)
#
# - [2.Exploratory Data Anlysis(EDA)](#2)
#     - [2.1 Exploring the dataset](#1.1)
#     - [2.2 Data Cleaning](#1.3)
#         - [2.3 Missing Value](#1.3.1)
#         - [2.3.2 Duplicated](#1.3.2)
#         - [2.3.3 Outliter](#1.3.3)
#
#     - [2.3 Diagnostics Analytics](#2.3)
# - [3. Data preprocessing and feature engineering](#4)
#
#     <!-- - [3.1 Min-Max Scaling or Standardization?](#4.1) -->
#     - [3.2 Encoding Categorical Variables](#4.2)
#         - [3.2.1 Label Encoding](#4.2.1)
#         - [3.2.2 One hot Encoding](#4.2.2)
#         - [3.2.3 Multicolinearity](#4.2.3)
# - [4. Data Splitting and Model Building](#5)
#    - [4.1 Model Buiding](#5.2)
#        - [4.1.1 Feature selection](#5.2.1)
#            - [4.1.1.1 Recursive Feature Elimination (RFE)](#5.2.1.1)
# - [5. Model Evaluation](#6)

# %% [markdown]
# ## 1. Exploring The dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression # linearRegression.fit(x_train, y_train)

# from sklearn.preprocessing import StandardScaler

import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('insurance.csv')

# %%
data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
data.tail()
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
data.iloc[200:205]
# Out:
#      age     sex     bmi  children smoker     region      charges
# 200   19  female  32.110         0     no  northwest   2130.67590
# 201   48  female  32.230         1     no  southeast   8871.15170
# 202   60  female  24.035         0     no  northwest  13012.20865
# 203   27  female  36.080         0    yes  southeast  37133.89820
# 204   46    male  22.300         0     no  southwest   7147.10500

# %%
data.loc[200:205]
# Out:
#      age     sex     bmi  children smoker     region      charges
# 200   19  female  32.110         0     no  northwest   2130.67590
# 201   48  female  32.230         1     no  southeast   8871.15170
# 202   60  female  24.035         0     no  northwest  13012.20865
# 203   27  female  36.080         0    yes  southeast  37133.89820
# 204   46    male  22.300         0     no  southwest   7147.10500
# 205   28  female  28.880         1     no  northeast   4337.73520

# %% [markdown]
# # 2. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### 2.1 Discovering

# %%
data.shape
# Out:
# (1338, 7)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %% [markdown]
# ### 2.2 Joining

# %% [markdown]
# ### 2.3 Validating
# You perform a quick check that the new data doesn’t have mistakes or misspellings.
#
# ### 2.4 Structuring
# You structure the data in different time periods and segments to understand trends.
# ### 2.5 Validating
# You do another quick check to ensure the new columns you’ve made in structuring are correctly designed.

# %% [markdown]
# ### 2.6 Cleaning
# You check for outliers, missing data, and needs for conversions or transformations,

# %% [markdown]
# #### 2.6.1 Missing values

# %%
## check missing value
data.isnull().sum()
data.dropna() ## drop missing value
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# ### 2.6.2 duplicated

# %%
data.duplicated().sum() ## check duplicated
data.drop_duplicates(inplace=True)

# %% [markdown]
# ### 2.6.3 Outlier

# %% [markdown]
# ### Age

# %%
fig, ax = plt.subplots(figsize = (16, 6))
ax.boxplot(x = data['age'])
plt.show()

# %%
sns.histplot(x = data['age'], kde=True, bins = 50)
plt.show()
## kernel density estimate (KDE)

# %%
fig, ax = plt.subplots(figsize = (6, 8))
sns.violinplot(y = data['age'])
plt.show()

# %%
sns.boxplot(x = data['age'])
# Out:
# <Axes: xlabel='age'>

# %%
data.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %% [markdown]
# ### charges

# %%
data['charges'].describe()
# Out:
# count     1337.000000
# mean     13279.121487
# std      12110.359656
# min       1121.873900
# 25%       4746.344000
# 50%       9386.161300
# 75%      16657.717450
# max      63770.428010
# Name: charges, dtype: float64

# %%
fig, ax = plt.subplots()
sns.histplot(x = data['charges'], bins = 50)
ax.spines[['right', 'top']].set_visible(False)
ax.set_title('Distribution of Chaeges', fontsize = 14, color ='r')
ax.set_xlabel('Charges', fontsize=12)
ax.set_ylabel('Frequency', fontsize=12)
fig.savefig('Distribution of Charges.png', dpi= 300)
plt.show()

# %%
sns.boxplot(data['charges'])
# Out:
# <Axes: >

# %%
data[data['charges']>40000].index
# Out:
# Index([  34,   39,   55,   86,   94,  109,  146,  175,  185,  251,  252,  254,
#         256,  265,  271,  281,  288,  292,  312,  327,  328,  330,  338,  381,
#         420,  421,  488,  530,  543,  549,  569,  577,  587,  615,  621,  629,
#         665,  667,  668,  674,  677,  682,  697,  706,  725,  736,  739,  742,
#         819,  826,  845,  852,  856,  860,  883,  893,  901,  951,  956,  958,
#        1022, 1031, 1047, 1062, 1090, 1096, 1111, 1122, 1124, 1146, 1152, 1218,
#        1230, 1240, 1241, 1284, 1300, 1301, 1323],
#       dtype='int64')

# %%
data.drop(index = data[data['charges']>40000].index,inplace=True)

# %%
data.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
# data_numeric = ['age', 'bmi', 'charges']
data_categorical = ['sex', 'smoker','region' ]

# %%
data[data_categorical]
# Out:
#          sex smoker     region
# 0     female    yes  southwest
# 1       male     no  southeast
# 2       male     no  southeast
# 3       male     no  northwest
# 4       male     no  northwest
# ...      ...    ...        ...
# 1333    male     no  northwest
# 1334  female     no  northeast
# 1335  female     no  southeast
# 1336  female     no  southwest
# 1337  female    yes  northwest
#
# [1258 rows x 3 columns]

# %%
# data[data_numeric]

# %%
# sns.boxplot(data[data_numeric])

# %%
# data[data_categorical]
# Out:
#          sex smoker     region
# 0     female    yes  southwest
# 1       male     no  southeast
# 2       male     no  southeast
# 3       male     no  northwest
# 4       male     no  northwest
# ...      ...    ...        ...
# 1333    male     no  northwest
# 1334  female     no  northeast
# 1335  female     no  southeast
# 1336  female     no  southwest
# 1337  female    yes  northwest
#
# [1258 rows x 3 columns]

# %%
data['sex'].value_counts()
# Out:
# sex
# female    630
# male      628
# Name: count, dtype: int64

# %%
sns.countplot(x = data['sex'], width=.3)
plt.show()

# %%
data['region'].value_counts()
# Out:
# region
# southeast    328
# southwest    311
# northwest    310
# northeast    309
# Name: count, dtype: int64

# %%
sns.countplot(x = data['region'], hue = data['sex']);

# %% [markdown]
# ![image.png](attachment:548edbb8-f892-4500-9d90-2472c2d9de41.png)![image.png](attachment:f4b0664b-d213-4099-97ac-4f31ac391832.png)

# %%
sns.histplot(x = data['age'])
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %% [markdown]
# ## Diagnostics

# %%
# data[data_numeric]

# %%
data_numeric = ['children','age', 'bmi', 'charges']

# %% [markdown]
# ### correlation coefficient

# %% [markdown]
# ## Scatter plot

# %%
sns.scatterplot(x = data['children'], y = data['charges'])
# Out:
# <Axes: xlabel='children', ylabel='charges'>

# %%
sns.scatterplot(x = data['age'], y = data['charges'])
# Out:
# <Axes: xlabel='age', ylabel='charges'>

# %%
data[data_numeric].corr()
# Out:
#           children       age       bmi   charges
# children  1.000000  0.049576  0.016409  0.140932
# age       0.049576  1.000000  0.144139  0.815179
# bmi       0.016409  0.144139  1.000000  0.043406
# charges   0.140932  0.815179  0.043406  1.000000

# %% [markdown]
# ## 3. Data preprocessing

# %%
data['charges'].describe()
# Out:
# count     1258.000000
# mean     11244.344235
# std       9182.733316
# min       1121.873900
# 25%       4527.756463
# 50%       8749.239125
# 75%      13911.859300
# max      39983.425950
# Name: charges, dtype: float64

# %%
data.shape
# Out:
# (1258, 7)

# %%
1258*.8
# Out:
# 1006.4000000000001

# %%
data.drop(index = data[data['charges']>17000].index, inplace=True)

# %%
data[data_numeric].corr()
# Out:
#           children       age       bmi   charges
# children  1.000000  0.049576  0.016409  0.140932
# age       0.049576  1.000000  0.144139  0.815179
# bmi       0.016409  0.144139  1.000000  0.043406
# charges   0.140932  0.815179  0.043406  1.000000

# %%
x = np.arange(2, 50, 5)
x
# Out:
# array([ 2,  7, 12, 17, 22, 27, 32, 37, 42, 47])

# %%
y = x*2 -3

# %%
y
# Out:
# array([ 1, 11, 21, 31, 41, 51, 61, 71, 81, 91])

# %%
sns.regplot(x = x, y = y)
plt.xticks(np.arange(0, 45, 2))
plt.yticks(np.arange(0, 90, 10))
plt.show()

# %%
sns.regplot(x = data['age'], y = data['charges'])
# Out:
# <Axes: xlabel='age', ylabel='charges'>

# %%
data.drop(index = data[(data['age']<30 )&
          (data['charges']>10000)].index, inplace=True)

# %%
data
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1      18    male  33.77         1     no  southeast   1725.5523
# 2      28    male  33.00         3     no  southeast   4449.4620
# 4      32    male  28.88         0     no  northwest   3866.8552
# 5      31  female  25.74         0     no  southeast   3756.6216
# 6      46  female  33.44         1     no  southeast   8240.5896
# ...   ...     ...    ...       ...    ...        ...         ...
# 1332   52  female  44.70         3     no  southwest  11411.6850
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
#
# [975 rows x 7 columns]

# %%
data[(data['age']<30 )& (data['charges']>10000)]
# Out:
# Empty DataFrame
# Columns: [age, sex, bmi, children, smoker, region, charges]
# Index: []

# %%
data[data_numeric].corr()
# Out:
#           children       age       bmi   charges
# children  1.000000  0.035175  0.016669  0.174001
# age       0.035175  1.000000  0.121219  0.956020
# bmi       0.016669  0.121219  1.000000  0.100563
# charges   0.174001  0.956020  0.100563  1.000000

# %%
# 100 * len(data[(data['age']<30 )& (data['charges']>10000)])/data.shape[0]

# %%
# data['charges'].quantile([0, 0.80])

# %% [markdown]
# ## change value as string to numeric

# %%
df = data.copy()

# %%
df
# Out:
#       age  sex    bmi  children  smoker     charges  region_northeast  \
# 1      18    1  33.77         1       0   1725.5523             False
# 2      28    1  33.00         3       0   4449.4620             False
# 4      32    1  28.88         0       0   3866.8552             False
# 5      31    0  25.74         0       0   3756.6216             False
# 6      46    0  33.44         1       0   8240.5896             False
# ...   ...  ...    ...       ...     ...         ...               ...
# 1332   52    0  44.70         3       0  11411.6850             False
# 1333   50    1  30.97         3       0  10600.5483             False
# 1334   18    0  31.92         0       0   2205.9808              True
# 1335   18    0  36.85         0       0   1629.8335             False
# 1336   21    0  25.80         0       0   2007.9450             False
#
#       region_northwest  region_southeast  region_southwest
# 1                False              True             False
# 2                False              True             False
# 4                 True             False             False
# 5                False              True             False
# 6                False              True             False
# ...                ...               ...               ...
# 1332             False             False              True
# 1333              True             False             False
# 1334             False             False             False
# 1335             False              True             False
# 1336             False             False              True
#
# [975 rows x 10 columns]

# %%
df['sex'].replace({'female':1,
                  'male':0}, inplace=True)

# %%
df['smoker'].replace({'no':0,
                     'yes':1}, inplace=True)

# %%
# df['region'].value_counts()

# %%
df = pd.get_dummies(data = df, prefix= 'region')

# %%
# #Label Encoding for (categorical variables)
# data['sex_l'] = LabelEncoder().fit_transform(data['sex'])
# data['smoker_l'] = LabelEncoder().fit_transform(data['smoker'])
# # data['region_l'] = LabelEncoder().fit_transform(data['region'])
# data

# %%
df
# Out:
#       age  sex    bmi  children  smoker     charges  region_northeast  \
# 1      18    1  33.77         1       0   1725.5523             False
# 2      28    1  33.00         3       0   4449.4620             False
# 4      32    1  28.88         0       0   3866.8552             False
# 5      31    0  25.74         0       0   3756.6216             False
# 6      46    0  33.44         1       0   8240.5896             False
# ...   ...  ...    ...       ...     ...         ...               ...
# 1332   52    0  44.70         3       0  11411.6850             False
# 1333   50    1  30.97         3       0  10600.5483             False
# 1334   18    0  31.92         0       0   2205.9808              True
# 1335   18    0  36.85         0       0   1629.8335             False
# 1336   21    0  25.80         0       0   2007.9450             False
#
#       region_northwest  region_southeast  region_southwest
# 1                False              True             False
# 2                False              True             False
# 4                 True             False             False
# 5                False              True             False
# 6                False              True             False
# ...                ...               ...               ...
# 1332             False             False              True
# 1333              True             False             False
# 1334             False             False             False
# 1335             False              True             False
# 1336             False             False              True
#
# [975 rows x 10 columns]

# %% [markdown]
# ## 4. Model building

# %%
### Split to train and test

# %%
from sklearn.model_selection import train_test_split

# %%
x = df.drop(columns='charges')
y = df['charges']
len(y)
# Out:
# 975

# %%
x
# Out:
#       age  sex    bmi  children  smoker  region_northeast  region_northwest  \
# 1      18    1  33.77         1       0             False             False
# 2      28    1  33.00         3       0             False             False
# 4      32    1  28.88         0       0             False              True
# 5      31    0  25.74         0       0             False             False
# 6      46    0  33.44         1       0             False             False
# ...   ...  ...    ...       ...     ...               ...               ...
# 1332   52    0  44.70         3       0             False             False
# 1333   50    1  30.97         3       0             False              True
# 1334   18    0  31.92         0       0              True             False
# 1335   18    0  36.85         0       0             False             False
# 1336   21    0  25.80         0       0             False             False
#
#       region_southeast  region_southwest
# 1                 True             False
# 2                 True             False
# 4                False             False
# 5                 True             False
# 6                 True             False
# ...                ...               ...
# 1332             False              True
# 1333             False             False
# 1334             False             False
# 1335              True             False
# 1336             False              True
#
# [975 rows x 9 columns]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1, random_state=90)

# %%
Linear_model = LinearRegression()

# %%
Linear_model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
Linear_model.score(x_train, y_train)
# Out:
# 0.9526607125563644

# %%
Linear_model.score(x_test, y_test)
# Out:
# 0.9806354607412396

# %%
Linear_model.intercept_
# Out:
# -3839.321670374008

# %%
x_train
# Out:
#       age  sex     bmi  children  smoker  region_northeast  region_northwest  \
# 553    52    0  31.730         2       0             False              True
# 1083   32    1  31.500         1       0             False             False
# 1319   39    0  26.315         2       0             False              True
# 560    46    0  19.950         2       0             False              True
# 711    50    0  23.540         2       0             False             False
# ...   ...  ...     ...       ...     ...               ...               ...
# 450    39    1  29.600         4       0             False             False
# 907    44    0  32.340         1       0             False             False
# 847    23    1  50.380         1       0             False             False
# 905    26    0  29.355         2       0              True             False
# 1173   38    1  29.260         2       0             False              True
#
#       region_southeast  region_southwest
# 553              False             False
# 1083             False              True
# 1319             False             False
# 560              False             False
# 711               True             False
# ...                ...               ...
# 450              False              True
# 907               True             False
# 847               True             False
# 905              False             False
# 1173             False             False
#
# [877 rows x 9 columns]

# %%
Linear_model.coef_
# Out:
# array([ 2.66000620e+02, -4.30047060e+02,  6.27878317e+00,  4.60174256e+02,
#         1.02252232e+04,  4.05146075e+02,  6.44376026e+01, -2.72218141e+02,
#        -1.97365536e+02])

# %%
x_train
# Out:
#       age  sex     bmi  children  smoker  region_northeast  region_northwest  \
# 553    52    0  31.730         2       0             False              True
# 1083   32    1  31.500         1       0             False             False
# 1319   39    0  26.315         2       0             False              True
# 560    46    0  19.950         2       0             False              True
# 711    50    0  23.540         2       0             False             False
# ...   ...  ...     ...       ...     ...               ...               ...
# 450    39    1  29.600         4       0             False             False
# 907    44    0  32.340         1       0             False             False
# 847    23    1  50.380         1       0             False             False
# 905    26    0  29.355         2       0              True             False
# 1173   38    1  29.260         2       0             False              True
#
#       region_southeast  region_southwest
# 553              False             False
# 1083             False              True
# 1319             False             False
# 560              False             False
# 711               True             False
# ...                ...               ...
# 450              False              True
# 907               True             False
# 847               True             False
# 905              False             False
# 1173             False             False
#
# [877 rows x 9 columns]

# %% [markdown]
# ![image.png](attachment:071fd893-43a9-4b80-aa80-14fdde626166.png)

# %%
x1 = x_train.iloc[:, 0:4]

# %%
x_train.replace({True:1, 
           False:0}, inplace=True)

# %%
x_train.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region_northeast',
#        'region_northwest', 'region_southeast', 'region_southwest'],
#       dtype='object')

# %%
x_train = x_train.drop(columns='bmi')

# %%
import statsmodels.api as sm

x_train_con1 = sm.add_constant(x_train)
model = sm.OLS(y_train,x_train_con1).fit()

# %%
x_train
# Out:
#       age  sex  children  smoker  region_northeast  region_northwest  \
# 553    52    0         2       0                 0                 1
# 1083   32    1         1       0                 0                 0
# 1319   39    0         2       0                 0                 1
# 560    46    0         2       0                 0                 1
# 711    50    0         2       0                 0                 0
# ...   ...  ...       ...     ...               ...               ...
# 450    39    1         4       0                 0                 0
# 907    44    0         1       0                 0                 0
# 847    23    1         1       0                 0                 0
# 905    26    0         2       0                 1                 0
# 1173   38    1         2       0                 0                 1
#
#       region_southeast  region_southwest
# 553                  0                 0
# 1083                 0                 1
# 1319                 0                 0
# 560                  0                 0
# 711                  1                 0
# ...                ...               ...
# 450                  0                 1
# 907                  1                 0
# 847                  1                 0
# 905                  0                 0
# 1173                 0                 0
#
# [877 rows x 8 columns]

# %%
x_test
# Out:
#       age  sex     bmi  children  smoker  region_northeast  region_northwest  \
# 1095   18    0  31.350         4       0              True             False
# 1330   57    0  25.740         2       0             False             False
# 690    21    1  27.360         0       0              True             False
# 565    19    0  30.495         0       0             False              True
# 145    29    0  38.830         3       0             False             False
# ...   ...  ...     ...       ...     ...               ...               ...
# 399    18    0  38.170         0       0             False             False
# 969    39    0  34.320         5       0             False             False
# 897    19    1  25.555         1       0             False              True
# 222    32    1  30.800         3       0             False             False
# 563    50    1  44.770         1       0             False             False
#
#       region_southeast  region_southwest
# 1095             False             False
# 1330              True             False
# 690              False             False
# 565              False             False
# 145               True             False
# ...                ...               ...
# 399               True             False
# 969               True             False
# 897              False             False
# 222              False              True
# 563               True             False
#
# [98 rows x 9 columns]

# %%
y_test
# Out:
# 1095     4561.18850
# 1330    12629.16560
# 690      2104.11340
# 565      2128.43105
# 145      5138.25670
#            ...
# 399      1631.66830
# 969      8596.82780
# 897      2221.56445
# 222      5253.52400
# 563      9058.73030
# Name: charges, Length: 98, dtype: float64

# %%
Linear_model.predict(x_test)
# Out:
# array([ 3391.37244068, 12132.45992209,  1893.57787399,  1470.59920617,
#         5226.80608767, 11733.32687952,  4494.15310221, 10902.85555862,
#         4687.86041371,  8717.60067651,  3476.67249248,  3296.64820934,
#         3963.68854616, 12036.48729659,  1778.65671038,  8010.43693898,
#         3907.37213235,  7481.19836345,  3393.44495554,  1967.90086566,
#         6779.51158339, 12476.83333097,   907.84450942,  1711.31842036,
#         4680.80415502, 12922.3450101 ,  5710.91902522,  1780.86457042,
#         8275.48477846,   711.59742169,  4575.65399746,  7134.22254847,
#         7685.03903012,  3452.51175817,   918.63305337,  6112.5179588 ,
#         4160.46949455,  9956.44994453,  9808.73930443,  1275.79931009,
#        11456.52941111,  7048.01258952,  9904.47959162,  4491.89732494,
#         9218.47059274, 10570.62635701,  3204.10124038, 11803.50993976,
#         8757.54324687, 11439.03218956,  2596.82375047,  1727.05607582,
#        12829.42751662,  6296.10583003,  4636.42803388, 12200.84045549,
#         7109.6651339 ,  3825.56333632,  3877.10118305,  5401.9662901 ,
#         1087.82171658,  3923.82713421, 10872.62680838,  9792.22574095,
#         1867.27013624,  9060.58868764,  2407.68458208,  9073.69547464,
#          435.66681483, 10348.78439565,  7836.17719095, 12159.67013746,
#         6488.52841495,  7754.36630572, 10705.59794693,  8621.34990265,
#          844.30322373, 11940.36057995, 10477.59082101,  5568.6751977 ,
#         9614.26918504,  1287.90149179,  3395.38171097, 12510.33978485,
#         1606.14846748,  2785.46976187,  2563.38023991,  5277.85980927,
#        10110.8175485 ,  9226.07758773,  8917.29734629,  3715.9653876 ,
#         5560.48740036,   916.1325032 ,  8778.84348746,  1469.70921343,
#         5619.19486428,  9499.71951025])

# %%
error  = y_test-Linear_model.predict(x_test)

# %%
error
# Out:
# 1095    1169.816059
# 1330     496.705678
# 690      210.535526
# 565      657.831844
# 145      -88.549388
#            ...
# 399      715.535797
# 969     -182.015687
# 897      751.855237
# 222     -365.670864
# 563     -440.989210
# Name: charges, Length: 98, dtype: float64

# %%
Linear_model.predict(x_test)
# Out:
# array([ 3391.37244068, 12132.45992209,  1893.57787399,  1470.59920617,
#         5226.80608767, 11733.32687952,  4494.15310221, 10902.85555862,
#         4687.86041371,  8717.60067651,  3476.67249248,  3296.64820934,
#         3963.68854616, 12036.48729659,  1778.65671038,  8010.43693898,
#         3907.37213235,  7481.19836345,  3393.44495554,  1967.90086566,
#         6779.51158339, 12476.83333097,   907.84450942,  1711.31842036,
#         4680.80415502, 12922.3450101 ,  5710.91902522,  1780.86457042,
#         8275.48477846,   711.59742169,  4575.65399746,  7134.22254847,
#         7685.03903012,  3452.51175817,   918.63305337,  6112.5179588 ,
#         4160.46949455,  9956.44994453,  9808.73930443,  1275.79931009,
#        11456.52941111,  7048.01258952,  9904.47959162,  4491.89732494,
#         9218.47059274, 10570.62635701,  3204.10124038, 11803.50993976,
#         8757.54324687, 11439.03218956,  2596.82375047,  1727.05607582,
#        12829.42751662,  6296.10583003,  4636.42803388, 12200.84045549,
#         7109.6651339 ,  3825.56333632,  3877.10118305,  5401.9662901 ,
#         1087.82171658,  3923.82713421, 10872.62680838,  9792.22574095,
#         1867.27013624,  9060.58868764,  2407.68458208,  9073.69547464,
#          435.66681483, 10348.78439565,  7836.17719095, 12159.67013746,
#         6488.52841495,  7754.36630572, 10705.59794693,  8621.34990265,
#          844.30322373, 11940.36057995, 10477.59082101,  5568.6751977 ,
#         9614.26918504,  1287.90149179,  3395.38171097, 12510.33978485,
#         1606.14846748,  2785.46976187,  2563.38023991,  5277.85980927,
#        10110.8175485 ,  9226.07758773,  8917.29734629,  3715.9653876 ,
#         5560.48740036,   916.1325032 ,  8778.84348746,  1469.70921343,
#         5619.19486428,  9499.71951025])

# %%
x_train1 = x_train.iloc[:, [0]]
x_train1
# Out:
#       age
# 553    52
# 1083   32
# 1319   39
# 560    46
# 711    50
# ...   ...
# 450    39
# 907    44
# 847    23
# 905    26
# 1173   38
#
# [877 rows x 1 columns]

# %%
x_train_con2 = sm.add_constant(x_train1)
model2 = sm.OLS(y_train,x_train_con2).fit()

# %%
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                charges   R-squared:                       0.910
# Model:                            OLS   Adj. R-squared:                  0.910
# Method:                 Least Squares   F-statistic:                     8835.
# Date:                Sun, 24 Mar 2024   Prob (F-statistic):               0.00
# Time:                        11:34:29   Log-Likelihood:                -7446.1
# No. Observations:                 877   AIC:                         1.490e+04
# Df Residuals:                     875   BIC:                         1.491e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -3416.7126    120.004    -28.472      0.000   -3652.241   -3181.184
# age          268.1388      2.853     93.996      0.000     262.540     273.738
# ==============================================================================
# Omnibus:                      725.406   Durbin-Watson:                   1.976
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            22406.427
# Skew:                           3.571   Prob(JB):                         0.00
# Kurtosis:                      26.710   Cond. No.                         127.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                charges   R-squared:                       0.953
# Model:                            OLS   Adj. R-squared:                  0.952
# Method:                 Least Squares   F-statistic:                     2494.
# Date:                Sun, 24 Mar 2024   Prob (F-statistic):               0.00
# Time:                        10:44:43   Log-Likelihood:                -7164.6
# No. Observations:                 877   AIC:                         1.435e+04
# Df Residuals:                     869   BIC:                         1.438e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const            -2929.3301     76.283    -38.401      0.000   -3079.051   -2779.609
# age                266.3542      2.081    127.984      0.000     262.270     270.439
# sex               -429.3304     58.088     -7.391      0.000    -543.339    -315.321
# children           460.3114     23.567     19.532      0.000     414.056     506.566
# smoker            1.016e+04    608.441     16.698      0.000    8965.801    1.14e+04
# region_northeast  -336.5350     54.754     -6.146      0.000    -444.001    -229.069
# region_northwest  -677.4177     53.397    -12.686      0.000    -782.220    -572.616
# region_southeast  -985.1625     53.783    -18.317      0.000   -1090.723    -879.602
# region_southwest  -930.2149     53.223    -17.478      0.000   -1034.676    -825.754
# ==============================================================================
# Omnibus:                      902.163   Durbin-Watson:                   1.963
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            54113.025
# Skew:                           4.785   Prob(JB):                         0.00
# Kurtosis:                      40.273   Cond. No.                     1.45e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 7.38e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
# !pip install explainerdashboard
# Out:
# Collecting explainerdashboard
#   Downloading explainerdashboard-0.4.7-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: click in /opt/anaconda3/lib/python3.11/site-packages (from explainerdashboard) (8.1.7)
# Collecting dash-auth (from explainerdashboard)
#   Downloading dash_auth-2.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting dash-bootstrap-components>=1 (from explainerdashboard)
#   Downloading dash_bootstrap_components-1.5.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting dash>=2.10.1 (from explainerdashboard)
#   Downloading dash-2.16.1-py3-none-any.whl.metadata (10 kB)
# Collecting dtreeviz>=2.1 (from explainerdashboard)
#   Downloading dtreeviz-2.2.2-py3-none-any.whl.metadata (2.4 kB)
# Collecting flask-simplelogin (from explainerdashboard)
#   Downloading flask_simplelogin-0.1.2-py3-none-any.whl.metadata (3.4 kB)
# Collecting Flask-WTF>=1.1 (from explainerdashboard)
#   Downloading flask_wtf-1.2.1-py3-none-any.whl.metadata (3.4 kB)
# Collecting graphviz>=0.18.2 (from explainerdashboard)
#   Downloading graphviz-0.20.3-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: joblib in /opt/anaconda3/lib/python3.11/site-packages (from explainerdashboard) (1.2.0)
# Collecting jupyter-dash>=0.4.1 (from explainerdashboard)
#   Downloading jupyter_dash-0.4.2-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.11/site-packages (from explainerdashboard) (1.23.5)
# Collecting oyaml (from explainerdashboard)
#   Downloading oyaml-1.0-py2.py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: pandas>=1.1 in /opt/anaconda3/lib/python3.11/site-packages (from explainerdashboard) (2.1.4)
# Requirement already satisfied: scikit-learn>=1.1 in /opt/anaconda3/lib/python3.11/site-packages (from explainerdashboard) (1.2.2)
# Collecting shap>=0.42.1 (from explainerdashboard)
#   Downloading shap-0.45.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (24 kB)
# Collecting waitress (from explainerdashboard)
#   Downloading waitress-3.0.0-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in /opt/anaconda3/lib/python3.11/site-packages (from dash>=2.10.1->explainerdashboard) (2.2.5)
# Requirement already satisfied: Werkzeug<3.1 in /opt/anaconda3/lib/python3.11/site-packages (from dash>=2.10.1->explainerdashboard) (2.2.3)
# Requirement already satisfied: plotly>=5.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from dash>=2.10.1->explainerdashboard) (5.9.0)
# Collecting dash-html-components==2.0.0 (from dash>=2.10.1->explainerdashboard)
#   Downloading dash_html_components-2.0.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting dash-core-components==2.0.0 (from dash>=2.10.1->explainerdashboard)
#   Downloading dash_core_components-2.0.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting dash-table==5.0.0 (from dash>=2.10.1->explainerdashboard)
#   Downloading dash_table-5.0.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: importlib-metadata in /opt/anaconda3/lib/python3.11/site-packages (from dash>=2.10.1->explainerdashboard) (7.0.1)
# Requirement already satisfied: typing-extensions>=4.1.1 in /opt/anaconda3/lib/python3.11/site-packages (from dash>=2.10.1->explainerdashboard) (4.9.0)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.11/site-packages (from dash>=2.10.1->explainerdashboard) (2.31.0)
# Collecting retrying (from dash>=2.10.1->explainerdashboard)
#   Downloading retrying-1.3.4-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: nest-asyncio in /opt/anaconda3/lib/python3.11/site-packages (from dash>=2.10.1->explainerdashboard) (1.6.0)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.11/site-packages (from dash>=2.10.1->explainerdashboard) (68.2.2)
# Requirement already satisfied: matplotlib in /opt/anaconda3/lib/python3.11/site-packages (from dtreeviz>=2.1->explainerdashboard) (3.8.0)
# Collecting colour (from dtreeviz>=2.1->explainerdashboard)
#   Downloading colour-0.1.5-py2.py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: pytest in /opt/anaconda3/lib/python3.11/site-packages (from dtreeviz>=2.1->explainerdashboard) (7.4.0)
# Requirement already satisfied: itsdangerous in /opt/anaconda3/lib/python3.11/site-packages (from Flask-WTF>=1.1->explainerdashboard) (2.0.1)
# Collecting wtforms (from Flask-WTF>=1.1->explainerdashboard)
#   Downloading wtforms-3.1.2-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: ipython in /opt/anaconda3/lib/python3.11/site-packages (from jupyter-dash>=0.4.1->explainerdashboard) (8.20.0)
# Requirement already satisfied: ipykernel in /opt/anaconda3/lib/python3.11/site-packages (from jupyter-dash>=0.4.1->explainerdashboard) (6.28.0)
# Collecting ansi2html (from jupyter-dash>=0.4.1->explainerdashboard)
#   Downloading ansi2html-1.9.1-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.11/site-packages (from pandas>=1.1->explainerdashboard) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas>=1.1->explainerdashboard) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas>=1.1->explainerdashboard) (2023.3)
# Requirement already satisfied: scipy>=1.3.2 in /opt/anaconda3/lib/python3.11/site-packages (from scikit-learn>=1.1->explainerdashboard) (1.11.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from scikit-learn>=1.1->explainerdashboard) (2.2.0)
# Requirement already satisfied: tqdm>=4.27.0 in /opt/anaconda3/lib/python3.11/site-packages (from shap>=0.42.1->explainerdashboard) (4.65.0)
# Requirement already satisfied: packaging>20.9 in /opt/anaconda3/lib/python3.11/site-packages (from shap>=0.42.1->explainerdashboard) (23.1)
# Collecting slicer==0.0.7 (from shap>=0.42.1->explainerdashboard)
#   Downloading slicer-0.0.7-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: numba in /opt/anaconda3/lib/python3.11/site-packages (from shap>=0.42.1->explainerdashboard) (0.59.0)
# Requirement already satisfied: cloudpickle in /opt/anaconda3/lib/python3.11/site-packages (from shap>=0.42.1->explainerdashboard) (2.2.1)
# Requirement already satisfied: pyyaml in /opt/anaconda3/lib/python3.11/site-packages (from oyaml->explainerdashboard) (6.0.1)
# Requirement already satisfied: Jinja2>=3.0 in /opt/anaconda3/lib/python3.11/site-packages (from Flask<3.1,>=1.0.4->dash>=2.10.1->explainerdashboard) (3.1.3)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from plotly>=5.0.0->dash>=2.10.1->explainerdashboard) (8.2.2)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=1.1->explainerdashboard) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/anaconda3/lib/python3.11/site-packages (from Werkzeug<3.1->dash>=2.10.1->explainerdashboard) (2.1.3)
# Requirement already satisfied: zipp>=0.5 in /opt/anaconda3/lib/python3.11/site-packages (from importlib-metadata->dash>=2.10.1->explainerdashboard) (3.17.0)
# Requirement already satisfied: appnope in /opt/anaconda3/lib/python3.11/site-packages (from ipykernel->jupyter-dash>=0.4.1->explainerdashboard) (0.1.2)
# Requirement already satisfied: comm>=0.1.1 in /opt/anaconda3/lib/python3.11/site-packages (from ipykernel->jupyter-dash>=0.4.1->explainerdashboard) (0.1.2)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/anaconda3/lib/python3.11/site-packages (from ipykernel->jupyter-dash>=0.4.1->explainerdashboard) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in /opt/anaconda3/lib/python3.11/site-packages (from ipykernel->jupyter-dash>=0.4.1->explainerdashboard) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/anaconda3/lib/python3.11/site-packages (from ipykernel->jupyter-dash>=0.4.1->explainerdashboard) (5.5.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /opt/anaconda3/lib/python3.11/site-packages (from ipykernel->jupyter-dash>=0.4.1->explainerdashboard) (0.1.6)
# Requirement already satisfied: psutil in /opt/anaconda3/lib/python3.11/site-packages (from ipykernel->jupyter-dash>=0.4.1->explainerdashboard) (5.9.0)
# Requirement already satisfied: pyzmq>=24 in /opt/anaconda3/lib/python3.11/site-packages (from ipykernel->jupyter-dash>=0.4.1->explainerdashboard) (25.1.2)
# Requirement already satisfied: tornado>=6.1 in /opt/anaconda3/lib/python3.11/site-packages (from ipykernel->jupyter-dash>=0.4.1->explainerdashboard) (6.3.3)
# Requirement already satisfied: traitlets>=5.4.0 in /opt/anaconda3/lib/python3.11/site-packages (from ipykernel->jupyter-dash>=0.4.1->explainerdashboard) (5.7.1)
# Requirement already satisfied: decorator in /opt/anaconda3/lib/python3.11/site-packages (from ipython->jupyter-dash>=0.4.1->explainerdashboard) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/anaconda3/lib/python3.11/site-packages (from ipython->jupyter-dash>=0.4.1->explainerdashboard) (0.18.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/anaconda3/lib/python3.11/site-packages (from ipython->jupyter-dash>=0.4.1->explainerdashboard) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /opt/anaconda3/lib/python3.11/site-packages (from ipython->jupyter-dash>=0.4.1->explainerdashboard) (2.15.1)
# Requirement already satisfied: stack-data in /opt/anaconda3/lib/python3.11/site-packages (from ipython->jupyter-dash>=0.4.1->explainerdashboard) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /opt/anaconda3/lib/python3.11/site-packages (from ipython->jupyter-dash>=0.4.1->explainerdashboard) (4.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->dtreeviz>=2.1->explainerdashboard) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->dtreeviz>=2.1->explainerdashboard) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->dtreeviz>=2.1->explainerdashboard) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->dtreeviz>=2.1->explainerdashboard) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->dtreeviz>=2.1->explainerdashboard) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->dtreeviz>=2.1->explainerdashboard) (3.0.9)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in /opt/anaconda3/lib/python3.11/site-packages (from numba->shap>=0.42.1->explainerdashboard) (0.42.0)
# Requirement already satisfied: iniconfig in /opt/anaconda3/lib/python3.11/site-packages (from pytest->dtreeviz>=2.1->explainerdashboard) (1.1.1)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /opt/anaconda3/lib/python3.11/site-packages (from pytest->dtreeviz>=2.1->explainerdashboard) (1.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.11/site-packages (from requests->dash>=2.10.1->explainerdashboard) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.11/site-packages (from requests->dash>=2.10.1->explainerdashboard) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.11/site-packages (from requests->dash>=2.10.1->explainerdashboard) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.11/site-packages (from requests->dash>=2.10.1->explainerdashboard) (2024.2.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/anaconda3/lib/python3.11/site-packages (from jedi>=0.16->ipython->jupyter-dash>=0.4.1->explainerdashboard) (0.8.3)
# Requirement already satisfied: platformdirs>=2.5 in /opt/anaconda3/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter-dash>=0.4.1->explainerdashboard) (3.10.0)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/lib/python3.11/site-packages (from pexpect>4.3->ipython->jupyter-dash>=0.4.1->explainerdashboard) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/anaconda3/lib/python3.11/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython->jupyter-dash>=0.4.1->explainerdashboard) (0.2.5)
# Requirement already satisfied: executing in /opt/anaconda3/lib/python3.11/site-packages (from stack-data->ipython->jupyter-dash>=0.4.1->explainerdashboard) (0.8.3)
# Requirement already satisfied: asttokens in /opt/anaconda3/lib/python3.11/site-packages (from stack-data->ipython->jupyter-dash>=0.4.1->explainerdashboard) (2.0.5)
# Requirement already satisfied: pure-eval in /opt/anaconda3/lib/python3.11/site-packages (from stack-data->ipython->jupyter-dash>=0.4.1->explainerdashboard) (0.2.2)
# Downloading explainerdashboard-0.4.7-py3-none-any.whl (287 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.8/287.8 kB 3.0 MB/s eta 0:00:00a 0:00:01
# Downloading dash-2.16.1-py3-none-any.whl (10.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 3.2 MB/s eta 0:00:0000:010:01m
# Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Downloading dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Downloading dash_bootstrap_components-1.5.0-py3-none-any.whl (221 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 221.2/221.2 kB 3.1 MB/s eta 0:00:00a 0:00:01
# Downloading dtreeviz-2.2.2-py3-none-any.whl (91 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.8/91.8 kB 4.1 MB/s eta 0:00:00
# Downloading flask_wtf-1.2.1-py3-none-any.whl (12 kB)
# Downloading graphviz-0.20.3-py3-none-any.whl (47 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.1/47.1 kB 3.3 MB/s eta 0:00:00
# Downloading jupyter_dash-0.4.2-py3-none-any.whl (23 kB)
# Downloading shap-0.45.0-cp311-cp311-macosx_11_0_arm64.whl (452 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 452.1/452.1 kB 3.1 MB/s eta 0:00:00a 0:00:01
# Downloading slicer-0.0.7-py3-none-any.whl (14 kB)
# Downloading dash_auth-2.3.0-py3-none-any.whl (14 kB)
# Downloading flask_simplelogin-0.1.2-py3-none-any.whl (7.2 kB)
# Downloading oyaml-1.0-py2.py3-none-any.whl (3.0 kB)
# Downloading waitress-3.0.0-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.7/56.7 kB 3.0 MB/s eta 0:00:00
# Downloading wtforms-3.1.2-py3-none-any.whl (145 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.0/146.0 kB 2.8 MB/s eta 0:00:00a 0:00:01
# Downloading ansi2html-1.9.1-py3-none-any.whl (17 kB)
# Downloading colour-0.1.5-py2.py3-none-any.whl (23 kB)
# Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Installing collected packages: dash-table, dash-html-components, dash-core-components, colour, wtforms, waitress, slicer, retrying, oyaml, graphviz, ansi2html, shap, Flask-WTF, dtreeviz, dash, flask-simplelogin, dash-bootstrap-components, dash-auth, jupyter-dash, explainerdashboard
# Successfully installed Flask-WTF-1.2.1 ansi2html-1.9.1 colour-0.1.5 dash-2.16.1 dash-auth-2.3.0 dash-bootstrap-components-1.5.0 dash-core-components-2.0.0 dash-html-components-2.0.0 dash-table-5.0.0 dtreeviz-2.2.2 explainerdashboard-0.4.7 flask-simplelogin-0.1.2 graphviz-0.20.3 jupyter-dash-0.4.2 oyaml-1.0 retrying-1.3.4 shap-0.45.0 slicer-0.0.7 waitress-3.0.0 wtforms-3.1.2

# %%
x_train
# Out:
#       age  sex  children  smoker  region_northeast  region_northwest  \
# 553    52    0         2       0                 0                 1
# 1083   32    1         1       0                 0                 0
# 1319   39    0         2       0                 0                 1
# 560    46    0         2       0                 0                 1
# 711    50    0         2       0                 0                 0
# ...   ...  ...       ...     ...               ...               ...
# 450    39    1         4       0                 0                 0
# 907    44    0         1       0                 0                 0
# 847    23    1         1       0                 0                 0
# 905    26    0         2       0                 1                 0
# 1173   38    1         2       0                 0                 1
#
#       region_southeast  region_southwest
# 553                  0                 0
# 1083                 0                 1
# 1319                 0                 0
# 560                  0                 0
# 711                  1                 0
# ...                ...               ...
# 450                  0                 1
# 907                  1                 0
# 847                  1                 0
# 905                  0                 0
# 1173                 0                 0
#
# [877 rows x 8 columns]

# %%
Linear_model2 = LinearRegression()
Linear_model2.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
x_train
# Out:
#       age  sex  children  smoker  region_northeast  region_northwest  \
# 553    52    0         2       0                 0                 1
# 1083   32    1         1       0                 0                 0
# 1319   39    0         2       0                 0                 1
# 560    46    0         2       0                 0                 1
# 711    50    0         2       0                 0                 0
# ...   ...  ...       ...     ...               ...               ...
# 450    39    1         4       0                 0                 0
# 907    44    0         1       0                 0                 0
# 847    23    1         1       0                 0                 0
# 905    26    0         2       0                 1                 0
# 1173   38    1         2       0                 0                 1
#
#       region_southeast  region_southwest
# 553                  0                 0
# 1083                 0                 1
# 1319                 0                 0
# 560                  0                 0
# 711                  1                 0
# ...                ...               ...
# 450                  0                 1
# 907                  1                 0
# 847                  1                 0
# 905                  0                 0
# 1173                 0                 0
#
# [877 rows x 8 columns]

# %%
Linear_model2.coef_
# Out:
# array([  266.3542086 ,  -429.33039947,   460.31135624, 10159.98599818,
#          395.79748331,    54.91483223,  -252.82997822,  -197.88233732])

# %%
from explainerdashboard import RegressionExplainer , ExplainerDashboard

explainer = RegressionExplainer(Linear_model2, x_train, y_train)
ExplainerDashboard(explainer).run()
# Out:
# WARNING: For shap='linear', shap interaction values can unfortunately not be calculated!
# Warning: shap values for shap.LinearExplainer get calculated against X_background, but paramater X_background=None, so using X instead
# Generating self.shap_explainer = shap.LinearExplainer(modelX)...
# Building ExplainerDashboard..
# Detected notebook environment, consider setting mode='external', mode='inline' or mode='jupyterlab' to keep the notebook interactive while the dashboard is running...
# For this type of model and model_output interactions don't work, so setting shap_interaction=False...
# The explainer object has no decision_trees property. so setting decision_trees=False...
# Generating layout...
# Calculating shap values...
# Calculating predictions...
# Calculating residuals...
# Calculating absolute residuals...
# Calculating dependencies...
# Calculating importances...
# Reminder: you can store the explainer (including calculated dependencies) with explainer.dump('explainer.joblib') and reload with e.g. ClassifierExplainer.from_file('explainer.joblib')
# Registering callbacks...
# Starting ExplainerDashboard on http://10.5.50.227:8050
#         <iframe
#             width="100%"
#             height="650"
#             src="http://0.0.0.0:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
def VIF(x):
    vif = pd.DataFrame({
        'Features': x.columns,
        'VIF': [variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
    })
    vif['VIF'] = vif['VIF'].round(2)
    vif = vif.sort_values(by='VIF', ascending=False).reset_index(drop=True)
    return vif

# %%
VIF(X_test)
